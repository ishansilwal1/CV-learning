# %%
import cv2 as cv 
import numpy as np 
import matplotlib.pyplot as plt 
img = cv.imread('image2.jpg')

plt.imshow(img[:,:,::-1])

# %%
img = cv.imread('image2.jpg')
img_bgr = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img_bgr)
img_rgb = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
## adding brightness and darkness 

matrix= np.ones(img.shape,dtype='uint8')*50
bright = cv.add(img,matrix)
plt.imshow(bright[:,:,::-1])

dark = cv.subtract(img,matrix)
plt.imshow(dark[:,:,::-1])

plt.figure(figsize=(10,10))
plt.subplot(131);plt.imshow(img[:,:,::-1]);plt.title('Original Image')
plt.subplot(132);plt.imshow(bright[:,:,::-1]);plt.title('Bright Image')
plt.subplot(133);plt.imshow(dark[:,:,::-1]);plt.title('Dark Image')
# Out:
# Text(0.5, 1.0, 'Dark Image')

# %%
img = cv.imread('image2.jpg')
img_bgr = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img_bgr)
img_rgb = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
#  # Image Contrasting

# %%
img = cv.imread('image2.jpg')

img_rgb = cv.cvtColor(img,cv.COLOR_BGR2RGB)


matrix1 = np.ones(img.shape,dtype='uint8')*1.5
matrix2 = np.ones(img.shape,dtype='uint8')*0.5

higher_contrast = np.uint8(cv.multiply(np.float64(img), matrix1))
lower_Contrast =  np.uint8(np.clip(cv.multiply(np.float64(img), matrix2), 0, 255))

plt.imshow(np.uint8(lower_Contrast)[:,:,::-1])
plt.imshow(np.uint8(higher_contrast)[:,:,::-1])

plt.figure(figsize=[18,5])
plt.subplot(131); plt.imshow(lower_Contrast); plt.title("Lower Contrast");
plt.subplot(132); plt.imshow(img_rgb);       plt.title("Original");
plt.subplot(133); plt.imshow(higher_contrast);plt.title("Higher Contrast");

# %% [markdown]
# <h1> Image Thresholding </h1>

# %% [markdown]
# <h3> Image thresholding is a technique for creating a binary image by seperating pixels into object and background </h3>
#  <ol><li>The process involves converting grayscale image to binary image </li>
#  <li>
#
#
#
#  </ol>
