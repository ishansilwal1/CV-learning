# %% [markdown]
# # Creating panaromas

# %%
import cv2 as cv 
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# 1. Find keypoints
# 2. find pairwise correspondence
# 3. Estimate pairwise homographs
# 4. refine homographs
# 5. stitch with blending
