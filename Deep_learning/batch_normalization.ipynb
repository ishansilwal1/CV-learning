# %% [markdown]
# # Batch Normalization

# %% [markdown]
# It is an algorithmic method which makes the training of Deep Neural Networks faster and more stable.
#
# (Good results in low epochs)
#
# Normalizes activation vectors from hidden layers using the mean and variance of the current batch .

# %% [markdown]
# Normalize means mean = 0 and standard deviation = 1
